# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Q1: Import seaborn library

# %%
# write your code here ^_^
import seaborn as sns

# %%
tips_dataset = sns.load_dataset('tips')

# %%
tips_dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Q2: Create a histogram, where the x-axis represents the tip column
# - Change the style to 'whitegrid'.
# - Split the data out by the day column's categories. Hint: use hue argument.
# - Handle the overlapping columns by switching the element argument over to step.

# %%
# write your code here ^_^
sns.set_style("whitegrid") # set style 

sns.histplot(data = tips_dataset, # set the data 
             x= 'tip', # set x data
             hue='day', #  set y data
             element='step' # set element argument
             )
plt.title('Tip Vs. day'); # set a title for the chart

# %% [markdown]
# ## Q2.1 Write your top three findings
# - Most tips are between 2$ to 4$
# - Tipping is more frequent in Saturday, Sunday and Thrusday
# - Saturday have the hightest tipping amount (around 10$)

# %% [markdown]
# # Q3: [Optional] Create a displot, where the x-axis represents the day column
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Handle the overlapping columns by switching the multiple argument over to 'dodge'.
# - Shrink the bars down using shrink argument to have a nice gap between each of them.
# - Change the bars color to 'Set1'.
# - Reset the hue order to ['Female', 'Male'].

# %%
# write your code here ^_^
sns.displot(data= tips_dataset, # set the data 
            x='day', # set x data 
            hue='sex', # set y data 
            multiple='dodge', # set multiple argument to dodge
            shrink=0.8 , # set shrink argument to 0.8 
            palette='Set1', # set color palette  
            hue_order=['Female','Male'] # set hue order
                       )
plt.title('Gender Vs. time');

# %% [markdown]
# ## Q3.1 Write your top three findings
# - Male are tipping more in Saturday and Sunday.
# - Friday have the lowest tipping count.
# - In Thrusday, the count of Male and female tipping is almost same.

# %% [markdown]
# # Q4: Create a ecdf plot, where the x-axis represents the tip column
# - Change the style to 'darkgrid'.
# - Change the font scale to 1.25.
# - Split the data out by the time column's categories. Hint: use hue argument.
# - Change the lines color to 'summer'.
# - Change the line width to 3.

# %%
# write your code here ^_^
sns.set_style("darkgrid") # set a style
sns.set(font_scale=1.25) # set a fontscale for the chart

sns.ecdfplot(data=tips_dataset, # set data 
             x = 'tip', # set x data
             hue='time', # set y data
             palette='summer', # set color palette
             linewidth=3 # set line width
             )
plt.title('Tip Vs. time'); # set a title for the chart

# %% [markdown]
# ## Q4.1 Write your top three findings
# - Dinner time have the highest tip amount.
# - The highet tipping amount in lunch time is around 6$.
# - The lunch and dinner time lines meets at 2$.

# %% [markdown]
# # Q5: [Optional] Create a box plot, where the x-axis represents the day column and the y-axis represents the tip column
# - Change the style to 'whitegrid'.
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Change the bars color to 'Paired'.
# - Reset the hue order to ['Female', 'Male'].
# - Change the line width to 2.5.

# %%
# write your code here ^_^
plt.figure(figsize=(10,8)) # set figure size
sns.set_style("whitegrid") # set figure style

sns.boxplot(data=tips_dataset, # set data
              x='day', # set x data
              y='tip', # set y data
              hue='sex', # set hue (color for each gender)
              palette='Paired', # set the palette 
              hue_order=['Female','Male'], # set the order of the hue
              linewidth=2.5 # set line width
              )
plt.title('Tip Vs. gender and day'); # set a title for the chart

# %% [markdown]
# ## Q5.1 Write your top three findings
# - Male in Saturday have the most outliers tipping amount.
# - Saturday have the lowest tipping amount for both male and female.
# - Female tip in Thursday more than male.

# %% [markdown]
# # Q6: Create a violin plot, where the x-axis represents the time column and the y-axis represents the tip column
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Split the violin so that each violin contains both sex column's categories. Hint: use split argument.
# - Change the shape of the inner part of the violin to 'quartiles'.
# - Change the violin color to 'Pastel1'.
# - Reset the hue order to ['Female', 'Male'].
# - Change the line width to 2.
# - Change the legend's location to The upper left.

# %%
# write your code here ^_^
plot_violin = sns.violinplot(data=tips_dataset, # set data
               x = 'time', # set x data
               y = 'tip', # set y data
               hue= 'sex', # set hue argument
               split='sex', # set split 
               inner ='quartiles', # set inner 
               palette='Pastel1', # set color palette
               hue_order=['Female','Male'], # set hue order
               linewidth = 2 # set line width                           
               )
sns.move_legend(plot_violin, 'upper left') # adjust the legend location
plt.title('Tip Vs. gender and time'); # set a title for the chart

# %% [markdown]
# ## Q6.1 Write your top three findings
# - Highest tipping amount is in the dinner time.
# - In lunch time most of the tipping amount is between 2$ and 4$
# - Female are tipping more than male at lunch time.

# %% [markdown]
# # Q7: [Optional] Create a swarm plot, where the x-axis represents the time column and the y-axis represents the total_bill column
# - Split the data out by the size column's categories. Hint: use hue argument.

# %%
# write your code here ^_^

sns.swarmplot(data= tips_dataset, # set data
              x='time', # set x data
              y='total_bill', # set y data
              hue='size' # set hue
              )
plt.title('Tip Vs. Total Bill'); # set title for the chart

# %% [markdown]
# ## Q7.1 Write your top three findings
# - Most dinner time have size of 2 guests.
# - Both dinner and luch time have an outliers.
# - Most of the data are at dinner time.

# %% [markdown]
# # Q8: Create a correlation heatmap
# - Adjust the figure's size to be (8,5).
# - Change the color map to 'RdBu'.
# - Add annotations to the heatmap.
# - Set the minimum value to be -1.
# - Set the maximum value to be 1.

# %%
# write your code here ^_^
plt.figure(figsize=(8,5)) # set figure size
sns.heatmap(tips_dataset.corr(), #set data correlation to plot
            cmap="RdBu", # set color 
            annot=True, # set annotation
            vmin=-1, # set minimum value
            vmax=1 # set maximum value
            )
plt.title('Correlation Heatmap'); # set title for chart

# %% [markdown]
# ## Q8.1 Write your top three findings
# - There is a relationship between tip, size and total_bill.
# - The relation between the column and itself is 1 (high correlation).
# - Size and tip have the lowest correlation value.

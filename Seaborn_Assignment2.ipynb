# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Q1: Import seaborn library

# %%
# write your code here ^_^
import seaborn as sns
sns.set()

# %%
tips_dataset = sns.load_dataset('tips')
tips_dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Q2: Create a histogram, where the x-axis represents the tip column
# - Change the style to 'whitegrid'.
# - Split the data out by the day column's categories. Hint: use hue argument.
# - Handle the overlapping columns by switching the element argument over to step.

# %%
plt.figure(figsize=(9,4))
sns.set_style('whitegrid')
sns.histplot(tips_dataset, x= 'tip', element = 'step' ,hue= 'day', palette = 'pastel',alpha = .6)
plt.title('Number of tip in every day',fontsize = 20, fontweight='bold')
plt.show()

# %% [markdown]
# ## Q2.1 Write your top three findings
# - Most tip in range from 1 to 7
# - Tip exist in Thur more than any other day
# - Least day for gitting tip is in Fri

# %% [markdown]
# # Q3: [Optional] Create a displot, where the x-axis represents the day column
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Handle the overlapping columns by switching the multiple argument over to 'dodge'.
# - Shrink the bars down using shrink argument to have a nice gap between each of them.
# - Change the bars color to 'Set1'.
# - Reset the hue order to ['Female', 'Male'].

# %%
plt.figure(figsize= (9,4))
sns.displot(data= tips_dataset,
            x= 'day', 
            hue= 'sex', 
            multiple= 'dodge',
            shrink= .8,
            palette = 'Set1', alpha= .6,
            hue_order= ['Female', 'Male'],
            kde=True)
plt.title('Number of Females and males visitors in every day',fontsize = 20, fontweight='bold')
plt.show()

# %% [markdown]
# ## Q3.1 Write your top three findings
# - Number of visiter in Fri day least than any other day
# - Most visitor for the resturant are male
# - Most visitor for the resturant are female only in Thur day

# %% [markdown]
# # Q4: Create a ecdf plot, where the x-axis represents the tip column
# - Change the style to 'darkgrid'.
# - Change the font scale to 1.25.
# - Split the data out by the time column's categories. Hint: use hue argument.
# - Change the lines color to 'summer'.
# - Change the line width to 3.

# %%
sns.set_style('darkgrid')
sns.set(font_scale =1.95)
sns.displot(
    tips_dataset,
    x= 'tip',
    hue= 'time',
    kind= 'ecdf', 
    linewidth= 3, 
    palette= 'summer',
    alpha=.6
)
plt.title('Proportion tip in lunch and dinner time', fontweight='bold')
plt.show()

# %% [markdown]
# ## Q4.1 Write your top three findings
# - Most tip happend during Dinner time.
# - Tip exist all the time
# - There is Positive relationship betweeen tip and proportion

# %% [markdown]
# # Q5: [Optional] Create a box plot, where the x-axis represents the day column and the y-axis represents the tip column
# - Change the style to 'whitegrid'.
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Change the bars color to 'Paired'.
# - Reset the hue order to ['Female', 'Male'].
# - Change the line width to 2.5.

# %%
plt.figure(figsize= (9,6))
sns.set_style('whitegrid')
sns.boxplot(
    data= tips_dataset, 
    x= 'day', 
    y= 'tip',
    hue= 'sex',
    palette= 'Paired',
    hue_order= ['Female', 'Male'],
    linewidth= 2.5
)
plt.title('Numbers of tips in every day', fontweight='bold')
plt.show()

# %% [markdown]
# ## Q5.1 Write your top three findings
# - Number of male visitor mare than female
# - There is outlier in Sat day
# - Mean tip in all day from 2- 3

# %% [markdown]
# # Q6: Create a violin plot, where the x-axis represents the time column and the y-axis represents the tip column
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Split the violin so that each violin contains both sex column's categories. Hint: use split argument.
# - Change the shape of the inner part of the violin to 'quartiles'.
# - Change the violin color to 'Pastel1'.
# - Reset the hue order to ['Female', 'Male'].
# - Change the line width to 2.
# - Change the legend's location to The upper left.

# %%
plt.figure(figsize= (4,6))
plt.title('Tips for Lunch and Dinner time for Female and Male', fontweight='bold')
sns.violinplot(data= tips_dataset, 
               x = 'time', 
               y = 'tip', 
               hue = 'sex',
               split= 'sex',
               inner = 'quartiles',
               palette = 'Pastel1', alpha =.6,
               hue_order= ['Female', 'Male'],
               linewidth= 2 , 
               legend ='upper left')
plt.show()

# %% [markdown]
# ## Q6.1 Write your top three findings
# - Number of tips for female is more than male in dinner and lunch time .
# - In dinner and lunch time the tips avrage between 1 - 6 dollar .
# - Tips in Dinner time up to more than 10 dollar.

# %% [markdown]
# # Q7: [Optional] Create a swarm plot, where the x-axis represents the time column and the y-axis represents the total_bill column
# - Split the data out by the size column's categories. Hint: use hue argument.

# %%
plt.figure(figsize= (8,6))
plt.title('Correlation for tips dataset', fontweight='bold')
sns.swarmplot(
    data= tips_dataset,
    x= 'time',
    y= 'total_bill', 
    hue= 'size'
)
plt.show()

# %% [markdown]
# ## Q7.1 Write your top three findings
# - Number of visitor in dinner time more than in lunch time
# - Order size 2 more demand than other size order
# - Avreage of total bill is between 10 to 35

# %% [markdown]
# # Q8: Create a correlation heatmap
# - Adjust the figure's size to be (8,5).
# - Change the color map to 'RdBu'.
# - Add annotations to the heatmap.
# - Set the minimum value to be -1.
# - Set the maximum value to be 1.

# %%
plt.figure(figsize=(8,5))
plt.title('Correlation for tips dataset', fontweight='bold')
sns.heatmap(tips_dataset.corr(), cmap= 'RdBu', annot= True, alpha= .6, vmin= -1, vmax= 1 )
plt.show()

# %% [markdown]
# ## Q8.1 Write your top three findings
# - Found positive Correlation
# - The relationship between size and tip lower
# - The relationship between total bill and tip is higher
